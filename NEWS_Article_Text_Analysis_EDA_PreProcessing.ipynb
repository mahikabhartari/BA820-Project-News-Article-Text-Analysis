# %% [markdown]
# <a href="https://colab.research.google.com/github/mahikabhartari/BA820-Project-News-Article-Text-Analysis/blob/main/NEWS_Article_Text_Analysis_EDA_PreProcessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##NEWS ARTICLE TEXT ANALYSIS

# %% [markdown]
# **Report Link :**
# Attaching the link to our report [here](https://docs.google.com/document/d/1zQPDQkYU19fPJhtLlfPx7744e2JkKurikSMt-Bk_2O8/edit#heading=h.iuzx9ovgx9z3).*italicized text*

# %% [markdown]
# #EDA

# %%
import pandas as pd
import numpy as np
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
import re
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from gensim.models import Word2Vec

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df1 = pd.read_csv('/content/drive/MyDrive/BA820_Project/one_percent_dataset_unclean.csv')

# %%
#printing head of the dataframe
df1.head()
# Out:
#          date  year  month  day       author  \
# 0  2017-09-01  2017      9    1  WIRED Staff
# 1  2018-03-01  2018      3    1  WIRED Staff
# 2  2016-07-01  2016      7    1  WIRED Staff
# 3  2016-04-01  2016      4    1  WIRED Staff
# 4  2019-04-01  2019      4    1  Emily Flake
#
#                                                title  \
# 0        The Physics of a 200 MPH Hyperloop Test Run
# 1  In the US v. Microsoft Supreme Court Case, an ...
# 2  NASA Confirms New Horizons Is Hurtling Towards...
# 3  Eye in the Sky Is the Quintessential Modern Wa...
# 4                  Blended Family, Hollywood Edition
#
#                                              article  \
# 0  The hyperloop, Elon Musk's idea to make a high...
# 1  On Tuesday, the Supreme Court heard oral argum...
# 2  Remember how excited you were last summer? No,...
# 3  The war film is one of cinema's most enduring ...
# 4  Moments after putting the finishing touches on...
#
#                                                  url   section publication  \
# 0  https://www.wired.com/story/hyperloop-200-mph-...   science       Wired
# 1  https://www.wired.com/story/us-v-microsoft-sup...  security       Wired
# 2  https://www.wired.com/2016/07/nasa-confirms-ne...   science       Wired
# 3  https://www.wired.com/2016/04/eye-in-the-sky-m...   culture       Wired
# 4  https://www.newyorker.com/magazine/2019/04/01/...  magazine  New Yorker
#
#                                  random  rowcnt
# 0  00f01d7b-33d8-4e92-8638-880773fbf1d7      78
# 1  016bf2aa-5f77-4c75-8be1-f9495949f4c0     123
# 2  017edd40-66cf-40b0-a22e-6f15d024533e     128
# 3  01a4c8dd-8ba5-457e-b5ae-11c9c1360f75     146
# 4  001f4a18-4e30-41ff-90a4-52454684758e       1

# %%
# number of rows and columns
df1.shape
# Out:
# (26751, 12)

# %%
#seeing the datatypes
df1.dtypes
# Out:
# date           object
# year            int64
# month           int64
# day             int64
# author         object
# title          object
# article        object
# url            object
# section        object
# publication    object
# random         object
# rowcnt          int64
# dtype: object

# %%
#checking for null values
df1.isna().sum()
# Out:
# date               0
# year               0
# month              0
# day                0
# author         10022
# title              0
# article          897
# url                0
# section         8961
# publication        0
# random             0
# rowcnt             0
# dtype: int64

# %%
#dropping null values from the og dataframe
df1.dropna(subset=['article'], inplace=True)

# %%
df1.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 26746    False
# 26747    False
# 26748    False
# 26749    False
# 26750    False
# Length: 25854, dtype: bool

# %%
df1.duplicated().value_counts()
# Out:
# False    25854
# dtype: int64

# %%
#number of duplicates in url
df1.duplicated(subset=['url']).sum()
# Out:
# 0

# %%
#number of duplicates in title
df1.duplicated(subset=['title']).sum()
# Out:
# 73

# %%
# checking for duplicates in the "title" column (sanity check)
duplicate_titles = df1[df1.duplicated(subset=['title'], keep=False)]
duplicate_titles
# Out:
#                       date  year  month  day          author  \
# 262    2017-10-01 11:10:01  2017     10    1      Sam Sifton
# 946    2018-02-02 00:00:00  2018      2    2  Tiernan Morgan
# 948    2018-03-02 00:00:00  2018      3    2  Tiernan Morgan
# 1066   2016-03-02 00:58:33  2016      3    2             NaN
# 1812   2017-11-03 14:45:00  2017     11    3      VICE Staff
# ...                    ...   ...    ...  ...             ...
# 25587  2017-07-30 00:00:00  2017      7   30  Hrag Vartanian
# 26062  2019-09-30 00:00:00  2019      9   30  Alex Gangitano
# 26415  2017-01-31 20:59:19  2017      1   31             NaN
# 26472           2019-07-31  2019      7   31             NaN
# 26525           2019-07-31  2019      7   31             NaN
#
#                                                    title  \
# 262                               What to Cook This Week
# 946                                        Art Movements
# 948                                        Art Movements
# 1066                                Quotation of the Day
# 1812                           The VICE Morning Bulletin
# ...                                                  ...
# 25587                                   Required Reading
# 26062                              Bottom Line | TheHill
# 26415                               Quotation of the Day
# 26472  Directors of Australia's Crown Resorts attack ...
# 26525  Directors of Australia's Crown Resorts attack ...
#
#                                                  article  \
# 262    What to Cook Sam Sifton emails readers of Cook...
# 946    This week in art news: a trucker drove across ...
# 948    This week in art news: a mafia member revealed...
# 1066   “You step in there, and it’s like you’re not e...
# 1812   Everything you need to know about the world th...
# ...                                                  ...
# 25587  This week, discussing ICA Boston’s new Schutz ...
# 26062  HEALTH CARE. Intact Vascular, Inc., a manufact...
# 26415  “America’s enemies feared it for dealing in fa...
# 26472  (Reuters) - Casino operator Crown Resorts (CWN...
# 26525  (Reuters) - Casino operator Crown Resorts (CWN...
#
#                                                      url  \
# 262    https://www.nytimes.com/2017/10/01/dining/what...
# 946    https://hyperallergic.com/424236/art-movements...
# 948    https://hyperallergic.com/429538/art-movements...
# 1066   http://www.nytimes.com/2016/03/02/todayspaper/...
# 1812   https://www.vice.com/en_us/article/59y59x/the-...
# ...                                                  ...
# 25587  https://hyperallergic.com/393185/required-read...
# 26062  https://thehill.com/business-a-lobbying/lobbyi...
# 26415  https://www.nytimes.com/2017/01/31/todayspaper...
# 26472  https://www.reuters.com/article/australia-crow...
# 26525  https://www.reuters.com/article/us-australia-c...
#
#                          section         publication  \
# 262                       dining  The New York Times
# 946                          NaN       Hyperallergic
# 948                          NaN       Hyperallergic
# 1066                 todayspaper  The New York Times
# 1812   The VICE Morning Bulletin                Vice
# ...                          ...                 ...
# 25587                        NaN       Hyperallergic
# 26062                        NaN            The Hill
# 26415                todayspaper  The New York Times
# 26472                 World News             Reuters
# 26525                 World News             Reuters
#
#                                      random  rowcnt
# 262    007e63a3-2a40-4345-a80e-f89429ebeee9     444
# 946    007ce1a9-2bc5-4227-8096-a5ee20e44bfb      26
# 948    013e6b00-881a-4678-81a4-a74d3d7f33e4      75
# 1066   0095ffad-3549-4734-963f-4c1c3ba0d6e2     531
# 1812   002732e0-10a5-47ab-9a33-21d213ce1ccd      53
# ...                                     ...     ...
# 25587  01e13158-3dbf-45a1-81b3-16d48890dc23     109
# 26062  00f30d39-7dff-4a01-8edf-bac1c92c29ac     791
# 26415  01da741a-36ba-4798-8b17-fba1cddf11c5    1755
# 26472  00a7ed8f-c711-4a85-ba0d-e50a48f51f81    2232
# 26525  01a6e4de-b834-4534-b48d-5375f9746b0c    5385
#
# [132 rows x 12 columns]

# %%
#counting occurrences of each duplicate title
duplicate_titles_only = duplicate_titles['title']
duplicate_titles_only.value_counts()
# Out:
# Deals of the day-Mergers and acquisitions                                                 5
# French and Benelux stocks-Factors to watch                                                4
# Quotation of the Day                                                                      4
# Required Reading                                                                          4
# Politics this week                                                                        4
# The VICE Morning Bulletin                                                                 3
# The Hill's 12:30 Report | TheHill                                                         3
# The Mail                                                                                  3
# EU must focus on avoiding cliff-edge in Brexit talks - senior EU official                 2
# Tu resumen de noticias del jueves                                                         2
# Tuesday Morning Briefing                                                                  2
# Rolls-Royce settles bribery probes in UK, U.S. and Brazil                                 2
# Pence aide said Trump's Ukraine phone call was 'unusual and inappropriate'                2
# Stars turn out for Mipcom television industry meeting in Cannes                           2
# Google Duo arrives to take on FaceTime                                                    2
# Jetmakers see brisk start to air show as UK tries to soothe Brexit worries                2
# New York Mets - PlayerWatch                                                               2
# New York Yankees - PlayerWatch                                                            2
# What to Cook This Week                                                                    2
# How a Texas oil CEO's luxury land deals cost him his job                                  2
# Briefly Noted Book Reviews                                                                2
# Cleveland Indians - PlayerWatch                                                           2
# Dunkin' Brands reports revenue below estimates                                            2
# France sets pesticide safe zones, angering both farmers and environmentalists             2
# Bottom Line | TheHill                                                                     2
# Shares of London-listed oil firms fall after Labour touts tax                             2
# Record profits at Hermes underscore luxury sector's upturn                                2
# Highlights From a Day of Campaigning in South Carolina and Super Tuesday States           2
# Once bulletproof, tech stocks now among market's biggest losers                           2
# Kobe Bryant Memorial: Full Coverage of the Tributes at Staples Center                     2
# At least two killed, others missing in Texas flooding                                     2
# Under pressure from Trump, Price resigns as health secretary over private plane uproar    2
# Tu resumen de noticias del martes                                                         2
# Putin says Russia knows real identity of men accused by UK over poisoning                 2
# What the Heck Is That?                                                                    2
# FACTBOX-Latest on the spread of coronavirus around the world                              2
# Recent Commercial Real Estate Transactions                                                2
# Atlanta Hawks - PlayerWatch                                                               2
# Utah Jazz - PlayerWatch                                                                   2
# St. Louis Cardinals - PlayerWatch                                                         2
# Miami Marlins - PlayerWatch                                                               2
# Philadelphia Phillies - PlayerWatch                                                       2
# Atlanta Braves - PlayerWatch                                                              2
# UPDATE 1-UK shoppers slow their spending ahead of Brexit, some stockpile                  2
# Deals of the day- Mergers and acquisitions                                                2
# Sunday shows so far                                                                       2
# 4 Film Series to Catch in N.Y.C. This Weekend                                             2
# San Diego Padres - PlayerWatch                                                            2
# Homes for Sale in Brooklyn and Manhattan                                                  2
# Milwaukee Bucks - PlayerWatch                                                             2
# Amid state dinner glamor, a serious agenda for Obama-Trudeau talks                        2
# Washington Nationals - PlayerWatch                                                        2
# Super Tuesday Aftermath: Sanders Acknowledges Setback After Biden’s Big Night             2
# German stocks - Factors to watch on August 9                                              2
# Reuters Business News Schedule at 0430 GMT/00.30AM ET                                     2
# Sacramento Kings - PlayerWatch                                                            2
# Hong Kong protesters scuffle with police, government offices shut                         2
# Art Movements                                                                             2
# Directors of Australia's Crown Resorts attack 'deceitful campaign' in letter              2
# Name: title, dtype: int64

# %%
#checking duplicates for articles as the same titled articles could belong to different timeline
df1.duplicated(subset=['article']).sum()
# Out:
# 115

# %%
#dropping duplicates
df1.drop_duplicates(subset=['article'], inplace=True)

# %%
#printing unique number of authors, sections, publications, year
df1['author'].unique()
# Out:
# array(['WIRED Staff', 'Emily Flake', 'Editorial Board', ...,
#        'By Brooke Brower, Ross Levitt and Wade Payson-Denney, CNN',
#        'By Abeer Salman with Andrew Carey, CNN', 'By Devan Cole'],
#       dtype=object)

# %%
df1['section'].unique()
# Out:
# array(['science', 'security', 'culture', 'magazine', nan, 'College',
#        'TERROR', 'Airlines', 'Media Buzz', 'OPINION', 'Jeep', 'asia',
#        'the-economist-explains', 'finance-and-economics', 'business',
#        'graphic-detail', 'europe', 'britain', 'leaders', 'international',
#        'TL;DR', 'Google', 'Reviews', 'Tech', 'Apps', 'Entertainment',
#        'Policy', 'Gaming', 'Business', 'Space', 'Fakes', 'Apple',
#        'Sploid', 'Health', 'Sports', 'Music by VICE', 'Food by VICE ',
#        'Tech by VICE', 'Comment', 'Travel', 'Identity', 'Noisey', 'Money',
#        'Islamic State', 'horoscopes', 'News by VICE', 'Astro Guide',
#        'nyregion', 'movies', 'sports', 'arts', 'fashion', 'us', 'health',
#        'books', 'world', 'podcasts', 'dining', 'travel', 'opinion',
#        't-magazine', 'upshot', 'learning', 'technology', 'theater',
#        'let-the-voting-begin', 'style', 'obituaries', 'Market News',
#        'Westlaw News', 'Business News', 'Communications Equipment',
#        'Company News', 'Advertising/Marketing', 'Environment',
#        'Funds News', 'Internet News', 'Financials', 'Asia', 'Intel',
#        'Technology News', 'U.S.', 'World News', 'Computer Hardware',
#        'Consumer Goods and Retail', 'Chinese Labor Unrest', 'US NFL',
#        'Sports News', 'Private Equity', 'Bankruptcy News', 'Healthcare',
#        'Earnings Season', 'Beverages - Brewers', 'Investment Services',
#        'Politics', 'Commodities', 'Bonds News',
#        'Non-Cyclical Consumer Goods', 'Software', 'Big Story 10',
#        'Industrials', 'Health News', 'Publishing', 'Deals',
#        'Olympics News', 'Energy', 'Brexit', 'Fintech',
#        'Entertainment Production', 'Semiconductors', 'Corrections News',
#        'Integrated Telecommunications Services', 'US NHL', 'Credit RSS',
#        'Cyber Risk', 'IT Services & Consulting', 'Hot Stocks', 'US NBA',
#        'Basic Materials', 'Switzerland Market Report', 'politics',
#        'music', 'babies', 'human-interest', 'celebrity', 'tv', 'food',
#        'pets', 'awards', 'home', 'royals', 'middleeast', 'opinions',
#        'entertainment', 'Economy', 'Wealth', 'Estimize',
#        'Personal Income', 'Markets', 'Investing', 'Wires',
#        'Personal Finance', 'Stocks', 'Retail',
#        'Weather & Natural Disasters', 'World Politics', 'Transportation',
#        'Autos', 'US Markets', 'Polls', 'Banks', 'Movies',
#        'Europe Markets', 'gear', 'Facebook', 'NHL', 'Travel Tips',
#        'EDUCATION', 'World', 'middle-east-and-africa', 'united-states',
#        'prospero', 'democracy-in-america', 'Smart Home', 'Report',
#        'First Click', 'Advice', 'Science', 'New Adventures', 'Genetics',
#        'Privacy and Security', 'Gadgets', 'News', 'Drugs', 'Comics!',
#        'Design', 'todayspaper', 'education', 'insider', 'briefing',
#        'climate', 'well', 'espanol', 'pageoneplus', 'crosswords',
#        'realestate', 'RPB', 'Apparel & Accessories',
#        'Technology, Media and Telecommunications',
#        'Beverages - Non-Alcoholic', 'Auto & Truck Manufacturers',
#        'Regulatory News - Americas', 'Entertainment News', 'Oddly Enough',
#        'Agriculture', 'Japan', 'Regulatory News - Asias', 'US MLB',
#        'Davos', 'parents', 'crime', 'chica', 'tech', 'media', 'Bitcoin',
#        'Media', 'Central Banks', 'Biotech and Pharma', 'Market Insider',
#        'Social Media', 'Real Estate', 'Wall Street', 'Earnings',
#        'FA Playbook', 'Health and Science', 'Cybersecurity',
#        'Asia Politics', 'Coronavirus', 'Federal Reserve', 'Oil and Gas',
#        'China Politics', 'transportation', 'US', 'TV', 'Mass Murder',
#        'Fast Food', 'Fitness + Well-being', 'Illegal Immigrants',
#        'Midterm Elections', 'special-report', 'the-americas',
#        'kaffeeklatsch', 'Microsoft', 'Featured Videos', 'CES 2019 News',
#        'Web', 'Samsung', 'The VICE Morning Bulletin', 'VICE News',
#        'Life Inside', 'Garage Magazine', 'Noisey Show', 'Sex',
#        'john-kasichs-plan-win-ohio-on-march-15-then-fight-at-the-convention',
#        'donald-trump-calls-david-duke-a-bad-person-and-mentions-a-third-party-run',
#        'US College Basketball', 'Mergers & Acquisitions - Americas',
#        'FRBtestC', 'Biotechnology', 'Broadcasting', 'U.S. Legal News',
#        'Breakingviews', 'Cyclical Consumer Goods', 'bodies', 'economy',
#        'perspectives', 'White House', 'Hedge Funds', 'CNBC News Releases',
#        'Bonds', 'Morning Brief', 'CCTV Transcripts', 'backchannel',
#        'design', 'photo', 'ideas', 'POLITICS', 'RELIGION', 'TERRORISM',
#        'Fires', 'books-and-arts', 'US & World', 'Field Guide', 'Giz Asks',
#        'Games', 'The VICE Guide to Right Now', '50 states of art',
#        'blanka-zizka-of-wilma-theater-wins-100000-vilcek-prize',
#        'march-4-2016-pictures-of-the-day', 'Lifestyle',
#        'Sustainable Business', 'Supreme Court',
#        'Semiconductor Equipment & Testing', 'breaking-news', 'country',
#        'investing', 'app-news-section', 'Asia Markets', 'E-Commerce',
#        'World Economy', 'Europe News', 'Oil', 'The Profit', 'Trade',
#        'Scandal', 'Transcript', 'IMMIGRATION', 'Exclusive', 'StoryStream',
#        'The Interface', "Tracking Trump's Congress", 'Broadly DK',
#        'sunday-review', 'whats-on-this-week-around-the-world-62', 'lens',
#        'Science News', 'Financial Regulatory Forum',
#        'US College Football', 'Hedge Funds - Americas', 'cnn10',
#        'Wars and Military Conflicts', 'Commentary', 'Currencies',
#        'Apparel', 'Press Releases', 'Metals', 'Restaurants', 'DISASTERS',
#        'Performance', 'National Anthem Protests', 'Soccer', 'Huawei',
#        'sculpture', 'The VICE Guide to the 2016 Election', 'aging',
#        'ted-cruz-doubles-down-on-carpet-bombing', 'nytnow',
#        'in-defense-of-funny-diagrams-wonkish',
#        'word-of-the-day-quiz-impalpable', 'your-money', 'reader-center',
#        'huang-yong-ping-brings-empires-of-globalization-to-paris',
#        'Financial Services and Real Estate', 'First Republic News',
#        'Rates RSS', 'RIO 2016', 'Foreign Exchange Analysis',
#        'Gold Market Report', 'Target LGBT', 'Enterprise',
#        'Investing in Space', 'Evolve', 'Elections', 'U.S. News',
#        'Leadership', 'Finance', 'CRIME', 'Couples', 'ENVIRONMENT',
#        'Babies', 'TRANSCRIPT', 'CONFLICTS', 'Photography', 'Photo Essay',
#        'Watch This', 'Mobile', 'Movie Review', 'Artificial Intelligence',
#        'Archaeology', 'immigration', 'Life',
#        'The VICE Guide to Right Now Podcast', 'civil-war-battle',
#        'Auto/Truck/Motorcycle Parts', 'Consumer Electronics', 'Arts',
#        'Esports', 'americas', 'Tourism', 'Futures & Commodities',
#        'US Economy', 'China Markets', 'Investor Toolkit',
#        'Celebrity Homes', 'TECH', 'Style + Beauty', 'Meghan Markle',
#        'open-future', "international women's day", '2018 election',
#        'musical urban legends', 'short film',
#        'diagnosis-lisa-sanders-pulsatile-tinnitus-fistula-chest-pain-hearing',
#        'bjdevtest', 'Big Story 12', 'Jobs', 'Asia-Pacific News',
#        'Health Insurance', 'Food & Beverage', 'Powering the Future',
#        'Taxes', 'Europe Politics', 'IPOs', 'Art & Culture', 'Tech Guide',
#        'Pharmaceuticals', 'Executive Edge', 'Music & Musicians',
#        'Political', 'Viral', 'Celebrity News', 'Safety',
#        'the-world-this-week', 'gulliver', 'Speech Online', '2020',
#        'pollution-tied-to-premature-births-especially-in-women-with-asthma',
#        'Appliances, Tools & Housewares', 'Advanced Medical Equipment',
#        'Casinos & Gaming', 'success', 'Europe Economy', 'Deals and IPOs',
#        'Asia Economy', 'Rare Diseases', 'obituary', 'Stream',
#        'Climate change', 'Physics', 'Motherboard', 'Corruption', 'scams',
#        'Top States for Business', 'Insects', 'Odd News',
#        'science-and-technology', 'Motherboard Homepage', 'Health ',
#        'john-kasich-says-negative-tone-of-jeb-bushs-campaign-could-hurt-family-name',
#        'the-weekly', 'singh-wedding-ring', 'Top News',
#        'Hedge Funds - Europes', 'Full coverage of the Winter Olympics.',
#        'africa', 'Out of Office', 'Trader Talk', 'Trading Nation',
#        'North Carolina', "Greg's Monologue", 'Royal Wedding',
#        'North Korea', 'Russia Investigation', 'Hands-on', 'Animals',
#        'Tunnel Vision', 'Beverages - Distillers & Wineries', 'Defense',
#        'Opinion - Politics', 'Government Shutdown', 'THE CLINTONS',
#        'Homicide', "Children's Health", 'game-theory', 'news', 'china',
#        'the-world-if', 'Podcasts', 'universal',
#        'educators-against-intolerance', 'Media News', 'Myanmar',
#        'The Brave Ones', 'Law and Regulations',
#        'Opinion - Invest in You: Ready. Set. Grow.', 'Kensho Stats',
#        'Verge Video', 'Amazon', 'abortion', 'Voices', 'Impact Work',
#        'national school walkout day',
#        'primary-stages-season-to-include-adaptation-of-rankines-citizen',
#        'bill-clinton-shares-memories-of-hillary-clintons-work-with-his-adversaries',
#        'Internet of Things', 'weather', 'GDP', 'Crime', 'Earthquakes',
#        'Good Deals', '10 Questions', 'Vice Blog', 'Studio Ghibli',
#        'tom-steyer-joins-forces-with-group-pushing-hispanic-candidates',
#        'jobs', 'weekly-news-quiz-march-8-14-2016', 'living',
#        'Portfolio Perspective', 'China Economy', 'Telecom', 'SHOWS',
#        'erasmus', 'automobiles', 'smarter-living', 'lifestyle',
#        'Immigration', 'Marijuana', 'At Work', 'Shark Tank', 'Europe',
#        'Accessories', 'free-exchange', 'Tech Policy', 'Buyables',
#        'canadian politics', 'Rise Up', 'public-editor', 'News Now',
#        'Special Reports', 'Crude Realities', 'Emerging Markets', 'NFL',
#        'New Jersey', 'MENTAL HEALTH', 'bagehots-notebook', 'letters',
#        'Concepts', 'Conspiracies', 'Views My Own', 'wuvable oaf',
#        'VICELAND ', 'Money Markets RSS', 'Mergers & Acquisitions - Asias',
#        'Technology Executive Council', 'Casinos and Gaming',
#        'Fixed Income Strategies', 'Latin America Markets', 'Rising Risks',
#        'As Seen On', 'christmas-specials', 'Stuff', 'Last Chance High',
#        'cars', 'Congress', 'Futures Now', 'Mad Money', 'Christianity',
#        'The Weather Front', 'How-to', 'BlackBerry',
#        'Privacy and Perception Issue', 'The Rundown',
#        'Reuters Fact Check', 'Reuters Backstory', 'Aerospace & Defense',
#        'Power Lunch', 'Guns and Weapons', 'Administration',
#        'Demographics', 'economic-and-financial-indicators', 'Computers',
#        'exhibitions', 'Impact Water', 'Criminal Justice',
#        '1966-artificial-heart-works', 'Big Story 15',
#        ' Millionaires & Billionaires', 'Housing', 'ETF Spotlight',
#        'American Greed', 'Trumponomics', 'Texas', 'London attack',
#        'kevin-mccarthy-g-o-p-house-leader-says-he-could-work-with-donald-trump',
#        'the-case-for-rubio-kasich', 'Healthcare Facilities',
#        'Crime and Punishment', 'Advice and the Advisor', 'Arkansas',
#        'Comedy', 'Circuit Breaker',
#        'des-moines-register-endorses-marco-rubio-and-hillary-clinton',
#        'Full coverage from Davos', 'intl_business', 'MILITARY', 'What If',
#        'puppy-amuser', 'ask-well-playing-with-unvaccinated-babies',
#        'IPOs - Americas', 'Utilities', 'London Market Report', 'India',
#        'Deals - Europe', 'Deaths', 'The Fed', 'Departed', 'Country',
#        'Fox News Halftime Report', 'Reptiles', 'Syria', 'Column',
#        'wildfires', 'Industry, Materials and Utilities', 'The Big Crunch',
#        'Advertising', 'Veterans', 'Hyundai', 'daily vice', 'TOYS', 'uber',
#        'Installation', 'G20', '100 Days of Trump', 'Tech Drivers', 'Law',
#        'Spaceflight', 'Hawaii', 'Office Equipment', 'Small Business',
#        'NCAA FB', 'Feuds', 'Nightlife',
#        'whats-going-on-in-this-picture-march-28-2016', 'India Top News',
#        'Invest in You: Ready. Set. Grow.',
#        'SPIEF: Russian elite gathers in St Petersburg ', 'New York',
#        'Box Office', 'Interview', 'Layoffs', 'Nonprofit Organization',
#        'The Deed: Chicago', 'CNBC Disruptor 50', 'Proud American',
#        'Extreme Foods', 'buttonwoods-notebook', 'Photo', 'loneliness',
#        'painting',
#        'uncomfortable-question-for-ted-cruz-on-obamacare-silences-the-room',
#        'Apple Inc', 'Marijuana Country: The Cannabis Boom',
#        'Tax Planning', 'Pop Up Start Up', 'Savings', '5 Things to Know',
#        'HOUSE OF REPRESENTATIVES', 'Competition', 'christmas', 'war',
#        'Department Stores'], dtype=object)

# %%
df1['year'].unique()
# Out:
# array([2017, 2018, 2016, 2019, 2020])

# %%
author_value_counts = df1['author'].value_counts()
author_counts_df = author_value_counts.reset_index()
author_counts_df.columns = ['Author', 'Count']
author_counts_df
# Out:
#                                                  Author  Count
# 0                                           WIRED Staff    164
# 1                                  The Associated Press     80
# 2                                      Associated Press     76
# 3                                     Field Level Media     69
# 4                                           John Bowden     66
# ...                                                 ...    ...
# 6422                                      Kara Scannell      1
# 6423  Michele Gelfand, University of Maryland psycho...      1
# 6424                            Chef Marcus Samuelsson       1
# 6425                                        Adrienne So      1
# 6426                                      By Devan Cole      1
#
# [6427 rows x 2 columns]

# %%
df1['title'].unique()
# Out:
# array(['The Physics of a 200 MPH Hyperloop Test Run',
#        'In the US v. Microsoft Supreme Court Case, an Old Law Leaves Few Good Options',
#        'NASA Confirms New Horizons Is Hurtling Towards Some Barren Space Rock Named 2014 MU69',
#        ...,
#        'UPDATE 3-GE posts loss, takes Boeing hit but raises forecast; CFO to leave',
#        'Here’s what caught my eye this morning: Trader',
#        "Moscow court case challenges city's facial recognition use after launch"],
#       dtype=object)

# %%
title_value_counts = df1['title'].value_counts()
title_counts_df = title_value_counts.reset_index()
title_counts_df.columns = ['Title', 'Count']
title_counts_df
# Out:
#                                                    Title  Count
# 0              Deals of the day-Mergers and acquisitions      5
# 1             French and Benelux stocks-Factors to watch      4
# 2                                   Quotation of the Day      4
# 3                                     Politics this week      4
# 4                                       Required Reading      4
# ...                                                  ...    ...
# 25675  Meet the Guy Selling Wireless Tech to Steal Lu...      1
# 25676    I'm Not OK: Remembering What It Meant to Be Emo      1
# 25677                    Daily Horoscopes: June 12, 2019      1
# 25678  Alabama Governor Resigns Before He Can Be Impe...      1
# 25679  Moscow court case challenges city's facial rec...      1
#
# [25680 rows x 2 columns]

# %%
df1['section'].unique()
# Out:
# array(['science', 'security', 'culture', 'magazine', nan, 'College',
#        'TERROR', 'Airlines', 'Media Buzz', 'OPINION', 'Jeep', 'asia',
#        'the-economist-explains', 'finance-and-economics', 'business',
#        'graphic-detail', 'europe', 'britain', 'leaders', 'international',
#        'TL;DR', 'Google', 'Reviews', 'Tech', 'Apps', 'Entertainment',
#        'Policy', 'Gaming', 'Business', 'Space', 'Fakes', 'Apple',
#        'Sploid', 'Health', 'Sports', 'Music by VICE', 'Food by VICE ',
#        'Tech by VICE', 'Comment', 'Travel', 'Identity', 'Noisey', 'Money',
#        'Islamic State', 'horoscopes', 'News by VICE', 'Astro Guide',
#        'nyregion', 'movies', 'sports', 'arts', 'fashion', 'us', 'health',
#        'books', 'world', 'podcasts', 'dining', 'travel', 'opinion',
#        't-magazine', 'upshot', 'learning', 'technology', 'theater',
#        'let-the-voting-begin', 'style', 'obituaries', 'Market News',
#        'Westlaw News', 'Business News', 'Communications Equipment',
#        'Company News', 'Advertising/Marketing', 'Environment',
#        'Funds News', 'Internet News', 'Financials', 'Asia', 'Intel',
#        'Technology News', 'U.S.', 'World News', 'Computer Hardware',
#        'Consumer Goods and Retail', 'Chinese Labor Unrest', 'US NFL',
#        'Sports News', 'Private Equity', 'Bankruptcy News', 'Healthcare',
#        'Earnings Season', 'Beverages - Brewers', 'Investment Services',
#        'Politics', 'Commodities', 'Bonds News',
#        'Non-Cyclical Consumer Goods', 'Software', 'Big Story 10',
#        'Industrials', 'Health News', 'Publishing', 'Deals',
#        'Olympics News', 'Energy', 'Brexit', 'Fintech',
#        'Entertainment Production', 'Semiconductors', 'Corrections News',
#        'Integrated Telecommunications Services', 'US NHL', 'Credit RSS',
#        'Cyber Risk', 'IT Services & Consulting', 'Hot Stocks', 'US NBA',
#        'Basic Materials', 'Switzerland Market Report', 'politics',
#        'music', 'babies', 'human-interest', 'celebrity', 'tv', 'food',
#        'pets', 'awards', 'home', 'royals', 'middleeast', 'opinions',
#        'entertainment', 'Economy', 'Wealth', 'Estimize',
#        'Personal Income', 'Markets', 'Investing', 'Wires',
#        'Personal Finance', 'Stocks', 'Retail',
#        'Weather & Natural Disasters', 'World Politics', 'Transportation',
#        'Autos', 'US Markets', 'Polls', 'Banks', 'Movies',
#        'Europe Markets', 'gear', 'Facebook', 'NHL', 'Travel Tips',
#        'EDUCATION', 'World', 'middle-east-and-africa', 'united-states',
#        'prospero', 'democracy-in-america', 'Smart Home', 'Report',
#        'First Click', 'Advice', 'Science', 'New Adventures', 'Genetics',
#        'Privacy and Security', 'Gadgets', 'News', 'Drugs', 'Comics!',
#        'Design', 'todayspaper', 'education', 'insider', 'briefing',
#        'climate', 'well', 'espanol', 'pageoneplus', 'crosswords',
#        'realestate', 'RPB', 'Apparel & Accessories',
#        'Technology, Media and Telecommunications',
#        'Beverages - Non-Alcoholic', 'Auto & Truck Manufacturers',
#        'Regulatory News - Americas', 'Entertainment News', 'Oddly Enough',
#        'Agriculture', 'Japan', 'Regulatory News - Asias', 'US MLB',
#        'Davos', 'parents', 'crime', 'chica', 'tech', 'media', 'Bitcoin',
#        'Media', 'Central Banks', 'Biotech and Pharma', 'Market Insider',
#        'Social Media', 'Real Estate', 'Wall Street', 'Earnings',
#        'FA Playbook', 'Health and Science', 'Cybersecurity',
#        'Asia Politics', 'Coronavirus', 'Federal Reserve', 'Oil and Gas',
#        'China Politics', 'transportation', 'US', 'TV', 'Mass Murder',
#        'Fast Food', 'Fitness + Well-being', 'Illegal Immigrants',
#        'Midterm Elections', 'special-report', 'the-americas',
#        'kaffeeklatsch', 'Microsoft', 'Featured Videos', 'CES 2019 News',
#        'Web', 'Samsung', 'The VICE Morning Bulletin', 'VICE News',
#        'Life Inside', 'Garage Magazine', 'Noisey Show', 'Sex',
#        'john-kasichs-plan-win-ohio-on-march-15-then-fight-at-the-convention',
#        'donald-trump-calls-david-duke-a-bad-person-and-mentions-a-third-party-run',
#        'US College Basketball', 'Mergers & Acquisitions - Americas',
#        'FRBtestC', 'Biotechnology', 'Broadcasting', 'U.S. Legal News',
#        'Breakingviews', 'Cyclical Consumer Goods', 'bodies', 'economy',
#        'perspectives', 'White House', 'Hedge Funds', 'CNBC News Releases',
#        'Bonds', 'Morning Brief', 'CCTV Transcripts', 'backchannel',
#        'design', 'photo', 'ideas', 'POLITICS', 'RELIGION', 'TERRORISM',
#        'Fires', 'books-and-arts', 'US & World', 'Field Guide', 'Giz Asks',
#        'Games', 'The VICE Guide to Right Now', '50 states of art',
#        'blanka-zizka-of-wilma-theater-wins-100000-vilcek-prize',
#        'march-4-2016-pictures-of-the-day', 'Lifestyle',
#        'Sustainable Business', 'Supreme Court',
#        'Semiconductor Equipment & Testing', 'breaking-news', 'country',
#        'investing', 'app-news-section', 'Asia Markets', 'E-Commerce',
#        'World Economy', 'Europe News', 'Oil', 'The Profit', 'Trade',
#        'Scandal', 'Transcript', 'IMMIGRATION', 'Exclusive', 'StoryStream',
#        'The Interface', "Tracking Trump's Congress", 'Broadly DK',
#        'sunday-review', 'whats-on-this-week-around-the-world-62', 'lens',
#        'Science News', 'Financial Regulatory Forum',
#        'US College Football', 'Hedge Funds - Americas', 'cnn10',
#        'Wars and Military Conflicts', 'Commentary', 'Currencies',
#        'Apparel', 'Press Releases', 'Metals', 'Restaurants', 'DISASTERS',
#        'Performance', 'National Anthem Protests', 'Soccer', 'Huawei',
#        'sculpture', 'The VICE Guide to the 2016 Election', 'aging',
#        'ted-cruz-doubles-down-on-carpet-bombing', 'nytnow',
#        'in-defense-of-funny-diagrams-wonkish',
#        'word-of-the-day-quiz-impalpable', 'your-money', 'reader-center',
#        'huang-yong-ping-brings-empires-of-globalization-to-paris',
#        'Financial Services and Real Estate', 'First Republic News',
#        'Rates RSS', 'RIO 2016', 'Foreign Exchange Analysis',
#        'Gold Market Report', 'Target LGBT', 'Enterprise',
#        'Investing in Space', 'Evolve', 'Elections', 'U.S. News',
#        'Leadership', 'Finance', 'CRIME', 'Couples', 'ENVIRONMENT',
#        'Babies', 'TRANSCRIPT', 'CONFLICTS', 'Photography', 'Photo Essay',
#        'Watch This', 'Mobile', 'Movie Review', 'Artificial Intelligence',
#        'Archaeology', 'immigration', 'Life',
#        'The VICE Guide to Right Now Podcast', 'civil-war-battle',
#        'Auto/Truck/Motorcycle Parts', 'Consumer Electronics', 'Arts',
#        'Esports', 'americas', 'Tourism', 'Futures & Commodities',
#        'US Economy', 'China Markets', 'Investor Toolkit',
#        'Celebrity Homes', 'TECH', 'Style + Beauty', 'Meghan Markle',
#        'open-future', "international women's day", '2018 election',
#        'musical urban legends', 'short film',
#        'diagnosis-lisa-sanders-pulsatile-tinnitus-fistula-chest-pain-hearing',
#        'bjdevtest', 'Big Story 12', 'Jobs', 'Asia-Pacific News',
#        'Health Insurance', 'Food & Beverage', 'Powering the Future',
#        'Taxes', 'Europe Politics', 'IPOs', 'Art & Culture', 'Tech Guide',
#        'Pharmaceuticals', 'Executive Edge', 'Music & Musicians',
#        'Political', 'Viral', 'Celebrity News', 'Safety',
#        'the-world-this-week', 'gulliver', 'Speech Online', '2020',
#        'pollution-tied-to-premature-births-especially-in-women-with-asthma',
#        'Appliances, Tools & Housewares', 'Advanced Medical Equipment',
#        'Casinos & Gaming', 'success', 'Europe Economy', 'Deals and IPOs',
#        'Asia Economy', 'Rare Diseases', 'obituary', 'Stream',
#        'Climate change', 'Physics', 'Motherboard', 'Corruption', 'scams',
#        'Top States for Business', 'Insects', 'Odd News',
#        'science-and-technology', 'Motherboard Homepage', 'Health ',
#        'john-kasich-says-negative-tone-of-jeb-bushs-campaign-could-hurt-family-name',
#        'the-weekly', 'singh-wedding-ring', 'Top News',
#        'Hedge Funds - Europes', 'Full coverage of the Winter Olympics.',
#        'africa', 'Out of Office', 'Trader Talk', 'Trading Nation',
#        'North Carolina', "Greg's Monologue", 'Royal Wedding',
#        'North Korea', 'Russia Investigation', 'Hands-on', 'Animals',
#        'Tunnel Vision', 'Beverages - Distillers & Wineries', 'Defense',
#        'Opinion - Politics', 'Government Shutdown', 'THE CLINTONS',
#        'Homicide', "Children's Health", 'game-theory', 'news', 'china',
#        'the-world-if', 'Podcasts', 'universal',
#        'educators-against-intolerance', 'Media News', 'Myanmar',
#        'The Brave Ones', 'Law and Regulations',
#        'Opinion - Invest in You: Ready. Set. Grow.', 'Kensho Stats',
#        'Verge Video', 'Amazon', 'abortion', 'Voices', 'Impact Work',
#        'national school walkout day',
#        'primary-stages-season-to-include-adaptation-of-rankines-citizen',
#        'bill-clinton-shares-memories-of-hillary-clintons-work-with-his-adversaries',
#        'Internet of Things', 'weather', 'GDP', 'Crime', 'Earthquakes',
#        'Good Deals', '10 Questions', 'Vice Blog', 'Studio Ghibli',
#        'tom-steyer-joins-forces-with-group-pushing-hispanic-candidates',
#        'jobs', 'weekly-news-quiz-march-8-14-2016', 'living',
#        'Portfolio Perspective', 'China Economy', 'Telecom', 'SHOWS',
#        'erasmus', 'automobiles', 'smarter-living', 'lifestyle',
#        'Immigration', 'Marijuana', 'At Work', 'Shark Tank', 'Europe',
#        'Accessories', 'free-exchange', 'Tech Policy', 'Buyables',
#        'canadian politics', 'Rise Up', 'public-editor', 'News Now',
#        'Special Reports', 'Crude Realities', 'Emerging Markets', 'NFL',
#        'New Jersey', 'MENTAL HEALTH', 'bagehots-notebook', 'letters',
#        'Concepts', 'Conspiracies', 'Views My Own', 'wuvable oaf',
#        'VICELAND ', 'Money Markets RSS', 'Mergers & Acquisitions - Asias',
#        'Technology Executive Council', 'Casinos and Gaming',
#        'Fixed Income Strategies', 'Latin America Markets', 'Rising Risks',
#        'As Seen On', 'christmas-specials', 'Stuff', 'Last Chance High',
#        'cars', 'Congress', 'Futures Now', 'Mad Money', 'Christianity',
#        'The Weather Front', 'How-to', 'BlackBerry',
#        'Privacy and Perception Issue', 'The Rundown',
#        'Reuters Fact Check', 'Reuters Backstory', 'Aerospace & Defense',
#        'Power Lunch', 'Guns and Weapons', 'Administration',
#        'Demographics', 'economic-and-financial-indicators', 'Computers',
#        'exhibitions', 'Impact Water', 'Criminal Justice',
#        '1966-artificial-heart-works', 'Big Story 15',
#        ' Millionaires & Billionaires', 'Housing', 'ETF Spotlight',
#        'American Greed', 'Trumponomics', 'Texas', 'London attack',
#        'kevin-mccarthy-g-o-p-house-leader-says-he-could-work-with-donald-trump',
#        'the-case-for-rubio-kasich', 'Healthcare Facilities',
#        'Crime and Punishment', 'Advice and the Advisor', 'Arkansas',
#        'Comedy', 'Circuit Breaker',
#        'des-moines-register-endorses-marco-rubio-and-hillary-clinton',
#        'Full coverage from Davos', 'intl_business', 'MILITARY', 'What If',
#        'puppy-amuser', 'ask-well-playing-with-unvaccinated-babies',
#        'IPOs - Americas', 'Utilities', 'London Market Report', 'India',
#        'Deals - Europe', 'Deaths', 'The Fed', 'Departed', 'Country',
#        'Fox News Halftime Report', 'Reptiles', 'Syria', 'Column',
#        'wildfires', 'Industry, Materials and Utilities', 'The Big Crunch',
#        'Advertising', 'Veterans', 'Hyundai', 'daily vice', 'TOYS', 'uber',
#        'Installation', 'G20', '100 Days of Trump', 'Tech Drivers', 'Law',
#        'Spaceflight', 'Hawaii', 'Office Equipment', 'Small Business',
#        'NCAA FB', 'Feuds', 'Nightlife',
#        'whats-going-on-in-this-picture-march-28-2016', 'India Top News',
#        'Invest in You: Ready. Set. Grow.',
#        'SPIEF: Russian elite gathers in St Petersburg ', 'New York',
#        'Box Office', 'Interview', 'Layoffs', 'Nonprofit Organization',
#        'The Deed: Chicago', 'CNBC Disruptor 50', 'Proud American',
#        'Extreme Foods', 'buttonwoods-notebook', 'Photo', 'loneliness',
#        'painting',
#        'uncomfortable-question-for-ted-cruz-on-obamacare-silences-the-room',
#        'Apple Inc', 'Marijuana Country: The Cannabis Boom',
#        'Tax Planning', 'Pop Up Start Up', 'Savings', '5 Things to Know',
#        'HOUSE OF REPRESENTATIVES', 'Competition', 'christmas', 'war',
#        'Department Stores'], dtype=object)

# %%
section_value_counts = df1['section'].value_counts()
section_counts_df = section_value_counts.reset_index()
section_counts_df.columns = ['Section', 'Count']
section_counts_df
# Out:
#                            Section  Count
# 0                       World News   1129
# 1                    Business News   1030
# 2                      Market News   1005
# 3                            Wires    665
# 4                         politics    547
# ..                             ...    ...
# 635              Children's Health      1
# 636                           news      1
# 637                   the-world-if      1
# 638  educators-against-intolerance      1
# 639              Department Stores      1
#
# [640 rows x 2 columns]

# %%
df1['publication'].unique()
# Out:
# array(['Wired', 'New Yorker', 'Washington Post', 'Vice News', 'TMZ',
#        'New Republic', 'Fox News', 'Axios', 'Economist', 'Refinery 29',
#        'Buzzfeed News', 'The Verge', 'Gizmodo', 'Hyperallergic',
#        'TechCrunch', 'Mashable', 'Vice', 'Vox', 'Business Insider',
#        'The New York Times', 'Reuters', 'People', 'Politico', 'The Hill',
#        'CNN', 'CNBC'], dtype=object)

# %%
publication_value_counts = df1['publication'].value_counts()
publication_counts_df = publication_value_counts.reset_index()
publication_counts_df.columns = ['Publication', 'Count']
publication_counts_df
# Out:
#            Publication  Count
# 0              Reuters   8241
# 1   The New York Times   2489
# 2                 CNBC   2342
# 3             The Hill   2021
# 4               People   1344
# 5                  CNN   1249
# 6                 Vice   1009
# 7             Mashable    941
# 8          Refinery 29    871
# 9     Business Insider    579
# 10          TechCrunch    519
# 11           The Verge    516
# 12                 TMZ    492
# 13               Axios    471
# 14                 Vox    471
# 15            Politico    462
# 16       Buzzfeed News    318
# 17             Gizmodo    272
# 18           Economist    238
# 19               Wired    202
# 20            Fox News    201
# 21           Vice News    155
# 22       Hyperallergic    134
# 23        New Republic    118
# 24          New Yorker     47
# 25     Washington Post     37

# %% [markdown]
# FURTHER ANALYSIS OF THE DATA

# %%
#groupping by publications to see the number of articles written by them
articles_by_publication = df1.groupby('publication').size().reset_index(name='num_articles')

#calculating the average word count per article for each author
avg_word_count = df1.groupby('publication')['article'].apply(lambda x: x.str.split().str.len().mean()).reset_index(name='avg_word_count')

#merging the two dataframes
publication_contribution = pd.merge(articles_by_publication, avg_word_count, on='publication')

# %%
#publication v/s articles
publication_contribution_sorted = publication_contribution.sort_values(by='num_articles', ascending=False)
publication_contribution_sorted
# Out:
#            publication  num_articles  avg_word_count
# 15             Reuters          8241      291.059095
# 19  The New York Times          2489      909.824829
# 3                 CNBC          2342      471.595645
# 18            The Hill          2021      580.356754
# 12              People          1344      429.875000
# 4                  CNN          1249      686.902322
# 21                Vice          1009      782.782953
# 9             Mashable           941      432.552604
# 14         Refinery 29           871      492.091848
# 1     Business Insider           579      801.982729
# 17          TechCrunch           519      576.314066
# 20           The Verge           516      558.812016
# 16                 TMZ           492      160.833333
# 0                Axios           471      233.959660
# 23                 Vox           471     1050.235669
# 13            Politico           462      731.599567
# 2        Buzzfeed News           318      842.820755
# 7              Gizmodo           272      596.205882
# 5            Economist           238      779.554622
# 25               Wired           202      522.207921
# 6             Fox News           201      635.348259
# 22           Vice News           155      813.406452
# 8        Hyperallergic           134      924.746269
# 10        New Republic           118      823.881356
# 11          New Yorker            47     2243.319149
# 24     Washington Post            37      679.351351

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#bar chart
plt.figure(figsize=(10, 6))
sns.barplot(x='publication', y= 'num_articles', data= publication_contribution_sorted, color= 'skyblue')
plt.title('Number of Articles by Publication')
plt.xlabel('Publication')
plt.ylabel('Number of Articles')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
#publication vs avg word count
publication_avgword_sorted = publication_contribution.sort_values(by='avg_word_count', ascending=False)
publication_avgword_sorted
# Out:
#            publication  num_articles  avg_word_count
# 11          New Yorker            47     2243.319149
# 23                 Vox           471     1050.235669
# 8        Hyperallergic           134      924.746269
# 19  The New York Times          2489      909.824829
# 2        Buzzfeed News           318      842.820755
# 10        New Republic           118      823.881356
# 22           Vice News           155      813.406452
# 1     Business Insider           579      801.982729
# 21                Vice          1009      782.782953
# 5            Economist           238      779.554622
# 13            Politico           462      731.599567
# 4                  CNN          1249      686.902322
# 24     Washington Post            37      679.351351
# 6             Fox News           201      635.348259
# 7              Gizmodo           272      596.205882
# 18            The Hill          2021      580.356754
# 17          TechCrunch           519      576.314066
# 20           The Verge           516      558.812016
# 25               Wired           202      522.207921
# 14         Refinery 29           871      492.091848
# 3                 CNBC          2342      471.595645
# 9             Mashable           941      432.552604
# 12              People          1344      429.875000
# 15             Reuters          8241      291.059095
# 0                Axios           471      233.959660
# 16                 TMZ           492      160.833333

# %%
# publication vs avg word count
plt.figure(figsize=(10, 6))
sns.barplot( x= 'publication', y='avg_word_count', data= publication_avgword_sorted, color= 'skyblue')
plt.title('Average Word Count by Publication')
plt.xlabel('Publication')
plt.ylabel('Average Word Count')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
#groupping by 'section' and count the number of articles in each section
section_distribution = df1.groupby('section').size().reset_index(name='num_articles')

#sorting sections by the number of articles in descending order
section_distribution_sorted = section_distribution.sort_values(by='num_articles', ascending=False)
top_10_sections = section_distribution_sorted.head(10)
top_10_sections
# Out:
#            section  num_articles
# 471     World News          1129
# 65   Business News          1030
# 264    Market News          1005
# 468          Wires           665
# 585       politics           547
# 168     Financials           543
# 628             us           527
# 233          Intel           401
# 326       Politics           336
# 58      Bonds News           312

# %%
import seaborn as sns
#plotting distribution of articles across sections
plt.figure(figsize=(10, 6))
sns.barplot(x='num_articles', y='section', data=top_10_sections, color= 'skyblue')
plt.title('Distribution of Articles Across Sections')
plt.xlabel('Number of Articles')
plt.ylabel('Section')
plt.show()

# %%
#time series

#extracting year from 'date' column
#df['year'] = df['date'].dt.year

#groupping by 'year' and count the number of articles for each year
articles_by_year = df1.groupby('year').size()

# %%
# plotting line chart
plt.figure(figsize=(10, 6))
plt.plot(articles_by_year.index.astype(int), articles_by_year.values, color='skyblue', marker='o', linestyle='--')
plt.title('Number of Articles by Year')
plt.xlabel('Year')
plt.ylabel('Number of Articles')
plt.xticks(articles_by_year.index.astype(int))  # Set x-axis ticks to be whole years

plt.show()

# %%
#word cloud
from collections import Counter
nltk.download('punkt')
title_tokens = [word for title in df1['title'] for word in word_tokenize(title.lower())]
title_word_freq = Counter(title_tokens)

title_word_freq.most_common(10)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [('to', 7199),
#  (',', 5634),
#  ('in', 4563),
#  ('the', 4448),
#  (':', 4155),
#  ('of', 3921),
#  ("'s", 3846),
#  ('for', 3233),
#  ('a', 2924),
#  ('on', 2773)]

# %%
from wordcloud import WordCloud


title_wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(title_word_freq)
plt.figure(figsize=(10, 5))
plt.imshow(title_wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud for Titles')
plt.show()

# %%
#taking a subset of articles because of the huge volume of words
df1_subset = df1.head(9000)

article_tokens = [word for article in df1_subset['article'] for word in word_tokenize(article.lower())]
article_word_freq = Counter(article_tokens)

# %%
article_wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(article_word_freq)
plt.figure(figsize=(10, 5))
plt.imshow(article_wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud for Articles')
plt.show()

# %% [markdown]
# #Pre-Processing

# %%
#importing cleaned dataframe
df1.to_csv('/content/drive/MyDrive/BA820_Project/cleaned_data_final.csv')

# %%
df = pd.read_csv('/content/drive/MyDrive/BA820_Project/cleaned_data_final.csv')

# %%
df.publication.value_counts(normalize =True).mul(100).round(2).astype(str) + '%'
# Out:
# Reuters               32.02%
# The New York Times     9.67%
# CNBC                    9.1%
# The Hill               7.85%
# People                 5.22%
# CNN                    4.85%
# Vice                   3.92%
# Mashable               3.66%
# Refinery 29            3.38%
# Business Insider       2.25%
# TechCrunch             2.02%
# The Verge               2.0%
# TMZ                    1.91%
# Axios                  1.83%
# Vox                    1.83%
# Politico               1.79%
# Buzzfeed News          1.24%
# Gizmodo                1.06%
# Economist              0.92%
# Wired                  0.78%
# Fox News               0.78%
# Vice News               0.6%
# Hyperallergic          0.52%
# New Republic           0.46%
# New Yorker             0.18%
# Washington Post        0.14%
# Name: publication, dtype: object

# %%
mdf = pd.read_html('https://components.one/datasets/all-the-news-2-news-articles-dataset')
mdf = mdf[1]
mdf
# Out:
#            Publication   Count
# 0                Axios   47815
# 1     Business Insider   57953
# 2        Buzzfeed News   32819
# 3                 CNBC  238096
# 4                  CNN  127602
# 5            Economist   26227
# 6             Fox News   20144
# 7              Gizmodo   27228
# 8        Hyperallergic   13551
# 9             Mashable   94107
# 10        New Republic   11809
# 11          New Yorker    4701
# 12              People  136488
# 13            Politico   46377
# 14         Refinery 29  111433
# 15             Reuters  840094
# 16                 TMZ   49595
# 17          TechCrunch   52095
# 18            The Hill  208411
# 19  The New York Times  252259
# 20           The Verge   52424
# 21                Vice  101137
# 22           Vice News   15539
# 23                 Vox   47272
# 24     Washington Post   40882
# 25               Wired   20243

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25739 entries, 0 to 25738
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   25739 non-null  int64
#  1   date         25739 non-null  object
#  2   year         25739 non-null  int64
#  3   month        25739 non-null  int64
#  4   day          25739 non-null  int64
#  5   author       16546 non-null  object
#  6   title        25739 non-null  object
#  7   article      25739 non-null  object
#  8   url          25739 non-null  object
#  9   section      17543 non-null  object
#  10  publication  25739 non-null  object
#  11  random       25739 non-null  object
#  12  rowcnt       25739 non-null  int64
# dtypes: int64(5), object(8)
# memory usage: 2.6+ MB

# %%
df.article = df.article.str.lower()
df.title = df.title.str.lower()
df['article'] = df['article'].fillna('')
df.article = df.article.str.replace('/^(https?:\/\/)?([\da-z\.-]+)\.([a-z\.]{2,6})([\/\w \.-]*)*\/?$/','',regex=True) #finding and dropping hyperlinks
df.article = df.article.str.replace('\d+','',regex=True) # dropping numbers
df.article = df.article.str.replace('[^\w\s]','',regex=True) # dropping trailing spaces
df.article = df.article.str.replace('[^a-zA-Z\s]','',regex=True)#non english characters

# %%
df
# Out:
#        Unnamed: 0                 date  year  month  day       author  \
# 0               0           2017-09-01  2017      9    1  WIRED Staff
# 1               1           2018-03-01  2018      3    1  WIRED Staff
# 2               2           2016-07-01  2016      7    1  WIRED Staff
# 3               3           2016-04-01  2016      4    1  WIRED Staff
# 4               4           2019-04-01  2019      4    1  Emily Flake
# ...           ...                  ...   ...    ...  ...          ...
# 25734       26746  2018-08-31 00:00:00  2018      8   31          NaN
# 25735       26747           2017-10-31  2017     10   31          NaN
# 25736       26748           2019-07-31  2019      7   31          NaN
# 25737       26749           2016-05-31  2016      5   31          NaN
# 25738       26750  2020-01-31 00:00:00  2020      1   31          NaN
#
#                                                    title  \
# 0            the physics of a 200 mph hyperloop test run
# 1      in the us v. microsoft supreme court case, an ...
# 2      nasa confirms new horizons is hurtling towards...
# 3      eye in the sky is the quintessential modern wa...
# 4                      blended family, hollywood edition
# ...                                                  ...
# 25734       how productive people utilize their time off
# 25735  white house releases official portraits of tru...
# 25736  update 3-ge posts loss, takes boeing hit but r...
# 25737     here’s what caught my eye this morning: trader
# 25738  moscow court case challenges city's facial rec...
#
#                                                  article  \
# 0      the hyperloop elon musks idea to make a highsp...
# 1      on tuesday the supreme court heard oral argume...
# 2      remember how excited you were last summer no n...
# 3      the war film is one of cinemas most enduring g...
# 4      moments after putting the finishing touches on...
# ...                                                  ...
# 25734  labor day can serve as the perfect excuse to s...
# 25735  the white house on tuesday released the first ...
# 25736  recasts updates shares july  reuters  general ...
# 25737  the potential for higher rates is causing agit...
# 25738  moscow jan  reuters  a court on friday will he...
#
#                                                      url   section  \
# 0      https://www.wired.com/story/hyperloop-200-mph-...   science
# 1      https://www.wired.com/story/us-v-microsoft-sup...  security
# 2      https://www.wired.com/2016/07/nasa-confirms-ne...   science
# 3      https://www.wired.com/2016/04/eye-in-the-sky-m...   culture
# 4      https://www.newyorker.com/magazine/2019/04/01/...  magazine
# ...                                                  ...       ...
# 25734  https://www.cnbc.com/2018/05/25/how-productive...       NaN
# 25735  https://www.cnbc.com/2017/10/31/white-house-re...  Politics
# 25736  https://www.cnbc.com/2019/07/31/reuters-americ...     Wires
# 25737  https://www.cnbc.com/2016/05/31/heres-what-cau...       NaN
# 25738  https://www.cnbc.com/2020/01/31/reuters-americ...     Wires
#
#       publication                                random  rowcnt
# 0           Wired  00f01d7b-33d8-4e92-8638-880773fbf1d7      78
# 1           Wired  016bf2aa-5f77-4c75-8be1-f9495949f4c0     123
# 2           Wired  017edd40-66cf-40b0-a22e-6f15d024533e     128
# 3           Wired  01a4c8dd-8ba5-457e-b5ae-11c9c1360f75     146
# 4      New Yorker  001f4a18-4e30-41ff-90a4-52454684758e       1
# ...           ...                                   ...     ...
# 25734        CNBC  0227b6aa-c585-476c-9054-0c3788d68d6a    1980
# 25735        CNBC  022e36e0-5645-4da9-b4fd-43c712751433    2008
# 25736        CNBC  023f8ff5-194c-4e0f-94b5-a8cbd0066fb5    2072
# 25737        CNBC  026bbf22-e263-4b81-a2a5-1b988cace45d    2232
# 25738        CNBC  027f1f9e-9855-43cf-9e61-9ea78b369446    2295
#
# [25739 rows x 13 columns]

# %% [markdown]
# #Vectorization

# %%
import nltk
from nltk.corpus import words
from sklearn.feature_extraction.text import CountVectorizer
from nltk.tokenize import word_tokenize
nltk.download('words')
nltk.download('punkt')
# creating a set for efficiency
english_words = set(words.words())
def english_only(text):
    return [token for token in word_tokenize(text) if token in english_words]

cv = CountVectorizer(tokenizer=english_only, stop_words='english')
dtm = cv.fit_transform(df.article)
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
len(cv.get_feature_names_out())
# Out:
# 33026

# %%
print('number of `tokens`', len(cv.vocabulary_))
cv.vocabulary_
# Out:
# number of `tokens` 33026
# {'idea': 13624,
#  'make': 16765,
#  'transit': 29592,
#  'people': 20484,
#  'exercise': 9827,
#  'despite': 7571,
#  'roster': 24342,
#  'piles': 20883,
#  'money': 17890,
#  'realizing': 22952,
#  'travel': 29649,
#  'nearly': 18449,
#  'airless': 649,
#  'tube': 29913,
#  'supersonic': 28028,
#  'human': 13416,
#  'taken': 28448,
#  'ride': 24102,
#  'date': 7009,
#  'theyre': 28973,
#  'case': 4219,
#  'musk': 18254,
#  'holding': 13150,
#  'ongoing': 19377,
#  'competition': 5523,
#  'student': 27639,
#  'build': 3661,
#  'test': 28855,
#  'weekend': 32291,
#  'pod': 21203,
#  'clock': 5062,
#  'highest': 13047,
#  'speed': 26810,
#  'built': 3666,
#  'campus': 3975,
#  'supreme': 28073,
#  'court': 6369,
#  'oral': 19471,
#  'argument': 1488,
#  'united': 30845,
#  'v': 31506,
#  'believe': 2514,
#  'significant': 25886,
#  'cloud': 5089,
#  'technology': 28678,
#  'interact': 14668,
#  'government': 12073,
#  'end': 9248,
#  'dispute': 8151,
#  'reach': 22911,
#  'act': 274,
#  'law': 15859,
#  'ability': 42,
#  'obtain': 19216,
#  'second': 25149,
#  'circuit': 4847,
#  'prominent': 22084,
#  'federal': 10339,
#  'appellate': 1337,
#  'new': 18599,
#  'york': 32938,
#  'warrant': 32137,
#  'does': 8346,
#  'allow': 793,
#  'require': 23742,
#  'production': 21994,
#  'server': 25423,
#  'relevant': 23497,
#  'provision': 22241,
#  'statute': 27232,
#  'apply': 1357,
#  'extraterritorially': 10045,
#  'data': 7008,
#  'expressed': 9971,
#  'unease': 30594,
#  'choose': 4757,
#  'word': 32701,
#  'long': 16432,
#  'remember': 23547,
#  'excited': 9776,
#  'summer': 27927,
#  'booth': 3199,
#  'state': 27201,
#  'fair': 10145,
#  'selling': 25256,
#  'deep': 7208,
#  'fried': 11256,
#  'beer': 2453,
#  'talking': 28470,
#  'ready': 22938,
#  'bout': 3299,
#  'excitement': 9778,
#  'target': 28553,
#  'lump': 16591,
#  'rock': 24246,
#  'belt': 2537,
#  'mu': 18125,
#  'dont': 8412,
#  'worry': 32747,
#  'exhausted': 9838,
#  'orbital': 19484,
#  'insertion': 14513,
#  'happening': 12638,
#  'th': 28889,
#  'rendezvous': 23584,
#  'st': 27082,
#  'plenty': 21122,
#  'time': 29173,
#  'better': 2644,
#  'way': 32227,
#  'spend': 26826,
#  'sitting': 26009,
#  'dark': 6985,
#  'waiting': 32052,
#  'space': 26702,
#  'probe': 21949,
#  'half': 12538,
#  'billion': 2722,
#  'away': 1956,
#  'send': 25320,
#  'home': 13175,
#  'confirming': 5742,
#  'successfully': 27839,
#  'war': 32105,
#  'film': 10530,
#  'enduring': 9282,
#  'major': 16761,
#  'conflict': 5750,
#  'past': 20221,
#  'century': 4424,
#  'times': 29184,
#  'wrestle': 32794,
#  'rapidly': 22838,
#  'nature': 18419,
#  'drone': 8630,
#  'warfare': 32117,
#  'slow': 26236,
#  'march': 16934,
#  'public': 22331,
#  'consciousness': 5825,
#  'eye': 10066,
#  'sky': 26096,
#  'best': 2626,
#  'movie': 18115,
#  'tackle': 28410,
#  'legal': 15972,
#  'moral': 17991,
#  'quagmire': 22541,
#  'surrounding': 28122,
#  'modern': 17813,
#  'technological': 28675,
#  'goes': 11987,
#  'granular': 12152,
#  'telling': 28732,
#  'story': 27468,
#  'particular': 20185,
#  'mission': 17741,
#  'day': 7027,
#  'opening': 19403,
#  'wide': 32475,
#  'today': 29274,
#  'colonel': 5320,
#  'secret': 25155,
#  'operation': 19414,
#  'capture': 4081,
#  'terrorist': 28847,
#  'cell': 4381,
#  'immediate': 13746,
#  'threat': 29038,
#  'situation': 26012,
#  'theres': 28949,
#  'landing': 15741,
#  'scene': 24890,
#  'examine': 9741,
#  'context': 5978,
#  'just': 15319,
#  'undercover': 30436,
#  'smattering': 26289,
#  'thats': 28906,
#  'international': 14747,
#  'resolved': 23804,
#  'clandestine': 4915,
#  'traditional': 29521,
#  'military': 17562,
#  'fought': 11123,
#  'battlefield': 2350,
#  'zone': 33014,
#  'problem': 21950,
#  'defined': 7263,
#  'geography': 11716,
#  'ideological': 13640,
#  'enemy': 9284,
#  'finishing': 10571,
#  'landmark': 15749,
#  'fox': 11143,
#  'entertainment': 9388,
#  'assets': 1665,
#  'walt': 32085,
#  'arduous': 1474,
#  'process': 21961,
#  'combining': 5373,
#  'massive': 17044,
#  'death': 7070,
#  'penalty': 20428,
#  'decline': 7168,
#  'used': 31468,
#  'popular': 21388,
#  'unnecessary': 30957,
#  'according': 183,
#  'report': 23679,
#  'information': 14356,
#  'center': 4403,
#  'represent': 23692,
#  'station': 27216,
#  'eventual': 9695,
#  'elimination': 9066,
#  'temporary': 28760,
#  'low': 16530,
#  'application': 1354,
#  'fifth': 10499,
#  'year': 32882,
#  'row': 24403,
#  'executed': 9812,
#  'population': 21395,
#  'longer': 16434,
#  'execute': 9811,
#  'abolition': 59,
#  'capital': 4053,
#  'punishment': 22412,
#  'northeastern': 18991,
#  'save': 24793,
#  'governor': 12075,
#  'moratorium': 18000,
#  'seven': 25449,
#  'responsible': 23838,
#  'large': 15781,
#  'share': 25559,
#  'west': 32340,
#  'handed': 12590,
#  'd': 6899,
#  'declared': 7164,
#  'ordered': 19498,
#  'san': 24676,
#  'execution': 9813,
#  'chamber': 4486,
#  'came': 3957,
#  'south': 26674,
#  'particularly': 20186,
#  'percent': 20502,
#  'mids': 17515,
#  'peak': 20345,
#  'late': 15813,
#  's': 24526,
#  'possibility': 21464,
#  'kill': 15460,
#  'innocent': 14456,
#  'person': 20628,
#  'necessarily': 18459,
#  'worst': 32756,
#  'capable': 4042,
#  'following': 10918,
#  'evidence': 9710,
#  'mental': 17324,
#  'illness': 13696,
#  'brain': 3353,
#  'injury': 14433,
#  'developmental': 7655,
#  'damage': 6936,
#  'intellectually': 14642,
#  'disabled': 7897,
#  'range': 22819,
#  'chronic': 4788,
#  'childhood': 4686,
#  'trauma': 29645,
#  'neglect': 18501,
#  'abuse': 124,
#  'little': 16323,
#  'wonder': 32654,
#  'heartening': 12836,
#  'opinion': 19425,
#  'said': 24595,
#  'poll': 21280,
#  'life': 16143,
#  'parole': 20159,
#  'murder': 18219,
#  'majority': 16763,
#  'position': 21448,
#  'trump': 29871,
#  'justice': 15320,
#  'department': 7444,
#  'memo': 17285,
#  'pushing': 22479,
#  'suddenly': 27860,
#  'unexpectedly': 30642,
#  'expensive': 9907,
#  'unfairly': 30657,
#  'unworthy': 31365,
#  'equal': 9490,
#  'applied': 1356,
#  'fairly': 10149,
#  'killing': 15463,
#  'nation': 18393,
#  'principle': 21908,
#  'individual': 14197,
#  'dignity': 7800,
#  'read': 22925,
#  'mockery': 17800,
#  'abolish': 57,
#  'f': 10085,
#  'shifting': 25650,
#  'business': 3796,
#  'view': 31794,
#  'entirely': 9400,
#  'union': 30832,
#  'vice': 31777,
#  'president': 21806,
#  'probably': 21945,
#  'thought': 29021,
#  'hard': 12656,
#  'good': 12020,
#  'strike': 27574,
#  'high': 13045,
#  'hearing': 12820,
#  'talk': 28465,
#  'week': 32289,
#  'tell': 28730,
#  'going': 11991,
#  'consider': 5853,
#  'illegal': 13681,
#  'right': 24123,
#  'conference': 5716,
#  'disagree': 7905,
#  'striking': 27576,
#  'average': 1924,
#  'rife': 24115,
#  'political': 21271,
#  'typical': 30086,
#  'lot': 16499,
#  'like': 16183,
#  'type': 30079,
#  'engage': 9295,
#  'rare': 22850,
#  'insist': 14533,
#  'walking': 32066,
#  'job': 15205,
#  'broad': 3521,
#  'commitment': 5444,
#  'sector': 25170,
#  'fighting': 10504,
#  'contract': 6008,
#  'poor': 21374,
#  'harmful': 12679,
#  'community': 5478,
#  'dozen': 8522,
#  'city': 4888,
#  'principal': 21906,
#  'demand': 7371,
#  'raise': 22774,
#  'revenue': 23983,
#  'taxing': 28626,
#  'rich': 24085,
#  'black': 2829,
#  'brown': 3578,
#  'sides': 25849,
#  'bearing': 2394,
#  'brunt': 3599,
#  'lewis': 16080,
#  'recently': 23058,
#  'numerous': 19087,
#  'budget': 3644,
#  'school': 24924,
#  'district': 8246,
#  'understand': 30506,
#  'recent': 23056,
#  'internal': 14742,
#  'leftist': 15965,
#  'militant': 17555,
#  'leadership': 15897,
#  'caucus': 4320,
#  'won': 32653,
#  'election': 9010,
#  'later': 15818,
#  'took': 29347,
#  'quarter': 22574,
#  'notable': 19012,
#  'multiple': 18183,
#  'near': 18446,
#  'days': 7032,
#  'mayor': 17153,
#  'power': 21556,
#  'player': 21085,
#  'national': 18394,
#  'democratic': 7385,
#  'party': 20198,
#  'track': 29507,
#  'record': 23134,
#  'antiunion': 1257,
#  'climate': 5024,
#  'turned': 29994,
#  'making': 16769,
#  'unwise': 31359,
#  'importantly': 13882,
#  'siding': 25855,
#  'message': 17379,
#  'appear': 1331,
#  'tribune': 29730,
#  'support': 28056,
#  'strong': 27607,
#  'clearly': 4987,
#  'come': 5378,
#  'jump': 15293,
#  'walk': 32063,
#  'territory': 28844,
#  'justification': 15323,
#  'specific': 26771,
#  'issue': 15052,
#  'unilateral': 30778,
#  'board': 3044,
#  'education': 8921,
#  'typically': 30087,
#  'continue': 5992,
#  'work': 32711,
#  'uncharted': 30310,
#  'previous': 21861,
#  'included': 14039,
#  'pay': 20321,
#  'related': 23472,
#  'number': 19078,
#  'spent': 26829,
#  'teaching': 28639,
#  'fall': 10162,
#  'decided': 7141,
#  'stop': 27449,
#  'giving': 11839,
#  'unfair': 30656,
#  'labor': 15635,
#  'practice': 21571,
#  'offense': 19282,
#  'bob': 3059,
#  'professor': 22011,
#  'director': 7885,
#  'university': 30855,
#  'program': 22046,
#  'clear': 4980,
#  'legality': 15975,
#  'established': 9603,
#  'private': 21931,
#  'risk': 24190,
#  'price': 21865,
#  'illegally': 13683,
#  'millions': 17586,
#  'briefly': 3483,
#  'sent': 25353,
#  'jail': 15098,
#  'automatic': 1891,
#  'ended': 9257,
#  'addition': 328,
#  'tightly': 29151,
#  'organized': 19518,
#  'favor': 10295,
#  'core': 6160,
#  'membership': 17282,
#  'engagement': 9297,
#  'priority': 21919,
#  'taking': 28450,
#  'office': 19292,
#  'knew': 15545,
#  'breaking': 3416,
#  'bring': 3505,
#  'republican': 23724,
#  'opposition': 19440,
#  'hallmark': 12548,
#  'did': 7746,
#  'exist': 9856,
#  'say': 24815,
#  'point': 21221,
#  'basis': 2305,
#  'educational': 8922,
#  'bigger': 2697,
#  'play': 21078,
#  'trying': 29901,
#  'change': 4507,
#  'fine': 10555,
#  'line': 16226,
#  'narrow': 18374,
#  'legally': 15978,
#  'permitted': 20591,
#  'social': 26480,
#  'appropriately': 1384,
#  'told': 29300,
#  'tonight': 29340,
#  'shortly': 25742,
#  'explaining': 9931,
#  'round': 24376,
#  'teacher': 28638,
#  'meant': 17179,
#  'arent': 1480,
#  'able': 49,
#  'accomplish': 178,
#  'basic': 2299,
#  'function': 11364,
#  'level': 16063,
#  'special': 26761,
#  'academy': 139,
#  'comes': 5386,
#  'amid': 925,
#  'battle': 2348,
#  'house': 13356,
#  'senate': 25317,
#  'equity': 9513,
#  'pass': 20204,
#  'service': 25424,
#  'close': 5071,
#  'drastically': 8560,
#  'reduce': 23227,
#  'currently': 6811,
#  'tax': 28618,
#  'financial': 10549,
#  'progressive': 22052,
#  'income': 14049,
#  'flat': 10702,
#  'constitutional': 5902,
#  'victory': 31789,
#  'define': 7262,
#  'showing': 25764,
#  'force': 10976,
#  'actually': 294,
#  'movement': 18113,
#  'fact': 10115,
#  'alongside': 815,
#  'unheard': 30746,
#  'happen': 12637,
#  'pretty': 21847,
#  'common': 5452,
#  'central': 4411,
#  'historical': 13101,
#  'evolution': 9722,
#  'policy': 21260,
#  'extraordinary': 10038,
#  'action': 277,
#  'economic': 8882,
#  'pursue': 22471,
#  'precedent': 21615,
#  'follow': 10916,
#  'twitter': 30070,
#  'look': 16448,
#  'pollution': 21297,
#  'age': 557,
#  'narrator': 18373,
#  'couple': 6357,
#  'baby': 2000,
#  'stroller': 27604,
#  'nose': 19002,
#  'hair': 12521,
#  'curling': 6802,
#  'man': 16824,
#  'partner': 20194,
#  'smiling': 26306,
#  'gaze': 11612,
#  'direction': 7879,
#  'young': 32941,
#  'child': 4683,
#  'sprouting': 27005,
#  'abundant': 122,
#  'environment': 9437,
#  'grown': 12347,
#  'enjoy': 9320,
#  'living': 16342,
#  'nasal': 18380,
#  'filter': 10535,
#  'bacteria': 2051,
#  'entering': 9381,
#  'china': 4705,
#  'announcement': 1110,
#  'smog': 26318,
#  'adaptation': 313,
#  'albeit': 695,
#  'highly': 13054,
#  'bizarre': 2825,
#  'air': 637,
#  'quality': 22552,
#  'produced': 21991,
#  'conservation': 5844,
#  'group': 12333,
#  'aware': 1953,
#  'contribute': 6028,
#  'commute': 5481,
#  'officer': 19294,
#  'percentage': 20503,
#  'use': 31467,
#  'daily': 6922,
#  'transportation': 29623,
#  'role': 24281,
#  'reducing': 23230,
#  'added': 322,
#  'sure': 28079,
#  'campaign': 3966,
#  'try': 29900,
#  'shape': 25550,
#  'encourage': 9238,
#  'consumer': 5934,
#  'personal': 20632,
#  'energy': 9288,
#  'consumption': 5938,
#  'video': 31791,
#  'million': 17584,
#  'wasnt': 32161,
#  'response': 23836,
#  'blamed': 2861,
#  'study': 27644,
#  'ranked': 22826,
#  'fourth': 11140,
#  'globally': 11903,
#  'factor': 10119,
#  'increase': 14102,
#  'higher': 13046,
#  'world': 32733,
#  'health': 12812,
#  'organization': 19514,
#  'safe': 24576,
#  'associated': 1679,
#  'press': 21811,
#  'unmanned': 30917,
#  'rocket': 24250,
#  'exploded': 9940,
#  'launch': 15841,
#  'site': 26006,
#  'manufacturer': 16907,
#  'running': 24490,
#  'falcon': 10161,
#  'missile': 17739,
#  'ahead': 617,
#  'cape': 4048,
#  'blast': 2888,
#  'set': 25436,
#  'extended': 9995,
#  'shook': 25715,
#  'nearby': 18447,
#  'blanketed': 2877,
#  'area': 1476,
#  'smoke': 26319,
#  'known': 15580,
#  'safety': 24580,
#  'emergency': 9141,
#  'management': 16829,
#  'representative': 23696,
#  'wing': 32545,
#  'nearest': 18448,
#  'unit': 30842,
#  'verge': 31707,
#  'satellite': 24750,
#  'belonging': 2535,
#  'operator': 19417,
#  'supposed': 28062,
#  'beam': 2381,
#  'undeveloped': 30544,
#  'initiative': 14422,
#  'mark': 16964,
#  'loss': 16496,
#  'trip': 29781,
#  'ironically': 14974,
#  'deeply': 7211,
#  'disappointed': 7914,
#  'hear': 12819,
#  'failure': 10138,
#  'provided': 22231,
#  'connectivity': 5805,
#  'continent': 5984,
#  'wrote': 32827,
#  'post': 21468,
#  'fateful': 10268,
#  'routine': 24397,
#  'procedure': 21956,
#  'strapped': 27512,
#  'rough': 24366,
#  'firm': 10599,
#  'land': 15736,
#  'upright': 31405,
#  'barge': 2236,
#  'pacific': 19901,
#  'ocean': 19241,
#  'tipped': 29224,
#  'touched': 29448,
#  'june': 15299,
#  'carrying': 4194,
#  'cargo': 4143,
#  'coast': 5134,
#  'booster': 3196,
#  'designed': 7551,
#  'returned': 23961,
#  'pad': 19914,
#  'cost': 6270,
#  'key': 15429,
#  'element': 9047,
#  'orbit': 19483,
#  'start': 27190,
#  'plan': 21030,
#  'slash': 26125,
#  'chief': 4676,
#  'fast': 10255,
#  'agenda': 562,
#  'impact': 13788,
#  'decision': 7151,
#  'dramatically': 8549,
#  'panel': 20019,
#  'blow': 3000,
#  'forcing': 10984,
#  'implement': 13865,
#  'methane': 17428,
#  'rule': 24462,
#  'tried': 29750,
#  'delay': 7317,
#  'main': 16749,
#  'tactics': 28421,
#  'employed': 9192,
#  'delaying': 7318,
#  'implementation': 13866,
#  'gut': 12458,
#  'agency': 561,
#  'considering': 5860,
#  'stay': 27239,
#  'comment': 5425,
#  'period': 20555,
#  'stayed': 27240,
#  'ruling': 24464,
#  'ball': 2117,
#  'effective': 8931,
#  'maneuver': 16846,
#  'sandbag': 24689,
#  'oil': 19316,
#  'gas': 11560,
#  'chemical': 4631,
#  'enact': 9212,
#  'subject': 27727,
#  'replacement': 23665,
#  'clean': 4970,
#  'water': 32189,
#  'likely': 16186,
#  'breakneck': 3417,
#  'pace': 19896,
#  'rolled': 24285,
#  'grapple': 12164,
#  'administration': 364,
#  'aggressive': 575,
#  'pull': 22370,
#  'extend': 9994,
#  'bush': 3791,
#  'environmental': 9438,
#  'executive': 9816,
#  'face': 10098,
#  'gone': 12014,
#  'important': 13881,
#  'assertion': 1656,
#  'authority': 1873,
#  'yes': 32913,
#  'seeing': 25203,
#  'effort': 8946,
#  'undermine': 30474,
#  'legitimacy': 15996,
#  'administrative': 365,
#  'altogether': 847,
#  'quickly': 22619,
#  'issuing': 15054,
#  'month': 17952,
#  'calling': 3939,
#  'shorter': 25738,
#  'decisively': 7153,
#  'enforce': 9289,
#  'regulation': 23380,
#  'keeping': 15390,
#  'natural': 18412,
#  'drilling': 8612,
#  'primarily': 21887,
#  'industry': 14228,
#  'plug': 21149,
#  'efficiency': 8940,
#  'help': 12919,
#  'curb': 6786,
#  'potent': 21516,
#  'greenhouse': 12225,
#  'traps': 29642,
#  'thirty': 29001,
#  'heat': 12851,
#  'carbon': 4095,
#  'dioxide': 7862,
#  'intergovernmental': 14708,
#  'based': 2291,
#  'enormous': 9345,
#  'noll': 18717,
#  'senior': 25326,
#  'attorney': 1805,
#  'integrity': 14637,
#  'news': 18607,
#  'difficult': 7772,
#  'roll': 24282,
#  'wade': 32024,
#  'senator': 25318,
#  'north': 18987,
#  'enthusiastic': 9394,
#  'supporter': 28058,
#  'search': 25116,
#  'giant': 11776,
#  'old': 19332,
#  'photo': 20778,
#  'knowledge': 15577,
#  'bigot': 2702,
#  'superimposed': 28006,
#  'big': 2694,
#  'red': 23172,
#  'latest': 15821,
#  'example': 9744,
#  'quick': 22616,
#  'click': 5015,
#  'declined': 7169,
#  'legislative': 15991,
#  'aide': 626,
#  'angrily': 1070,
#  'picture': 20847,
#  'current': 6810,
#  'listed': 16291,
#  'ideology': 13643,
#  'surfaced': 28086,
#  'midst': 17519,
#  'tough': 29455,
#  'marketing': 16974,
#  'democrat': 7384,
#  'racially': 22700,
#  'benefit': 2570,
#  'newly': 18604,
#  'local': 16369,
#  'indivisible': 14204,
#  'flip': 10772,
#  'attempt': 1790,
#  'break': 3409,
#  'legislature': 15994,
#  'override': 19804,
#  'went': 32335,
#  'receive': 23052,
#  'statement': 27210,
#  'automatically': 1892,
#  'web': 32273,
#  'fix': 10643,
#  'isolated': 15039,
#  'incident': 14023,
#  'tech': 28664,
#  'primary': 21888,
#  'box': 3320,
#  'acknowledged': 237,
#  'error': 9558,
#  'really': 22955,
#  'fault': 10287,
#  'rely': 23527,
#  'populate': 21394,
#  'vandalize': 31578,
#  'reliance': 23502,
#  'leaving': 15939,
#  'open': 19400,
#  'doesnt': 8347,
#  'activist': 285,
#  'comer': 5385,
#  'upset': 31413,
#  'amendment': 915,
#  'banning': 2194,
#  'civil': 4893,
#  'ultimately': 30121,
#  'let': 16043,
#  'plainly': 21022,
#  'appropriate': 1383,
#  'measure': 17184,
#  'forever': 11028,
#  'entire': 9399,
#  'minority': 17638,
#  'citizenship': 4881,
#  'serving': 25429,
#  'council': 6298,
#  'respond': 23833,
#  'request': 23740,
#  'involve': 14938,
#  'misinformation': 17712,
#  'bias': 2667,
#  'unwillingness': 31355,
#  'inability': 13949,
#  'monitor': 17901,
#  'meddling': 17204,
#  'hotly': 13346,
#  'controversy': 6040,
#  'silicon': 25903,
#  'valley': 31555,
#  'cynical': 6890,
#  'overreliance': 19802,
#  'volunteer': 31982,
#  'cover': 6386,
#  'image': 13716,
#  'la': 15631,
#  'legend': 15979,
#  'jack': 15080,
#  'team': 28644,
#  'town': 29480,
#  'git': 11835,
#  'hall': 12546,
#  'specifically': 26772,
#  'answer': 1142,
#  'hell': 12909,
#  'looking': 16450,
#  'unload': 30898,
#  'jersey': 15170,
#  'mansion': 16895,
#  'family': 10192,
#  'market': 16970,
#  'divorce': 8305,
#  'sprawling': 26981,
#  'residence': 23781,
#  'cool': 6101,
#  'sweet': 28211,
#  'master': 17049,
#  'suite': 27900,
#  'huge': 13403,
#  'plus': 21176,
#  'marble': 16924,
#  'bath': 2330,
#  'steam': 27259,
#  'shower': 25762,
#  'topnotch': 29376,
#  'basketball': 2308,
#  'patio': 20273,
#  'koi': 15593,
#  'pond': 21351,
#  'fireplace': 10591,
#  'room': 24312,
#  'gourmet': 12065,
#  'kitchen': 15522,
#  'decked': 7155,
#  'granite': 12147,
#  'custom': 6849,
#  'cabinetry': 3868,
#  'pantry': 20049,
#  'island': 15031,
#  'oh': 19312,
#  'rotunda': 24363,
#  'banker': 2186,
#  'listing': 16296,
#  'permanent': 20580,
#  'drake': 8545,
#  'harden': 12658,
#  'saying': 24818,
#  'triple': 29784,
#  'double': 8462,
#  'game': 11501,
#  'pure': 22436,
#  'madness': 16689,
#  'star': 27168,
#  'hung': 13465,
#  'nye': 19117,
#  'posting': 21484,
#  'caught': 4322,
#  'attention': 1794,
#  'gave': 11604,
#  'shout': 25754,
#  'nick': 18635,
#  'night': 18650,
#  'bumping': 3713,
#  'music': 18246,
#  'loud': 16507,
#  'rental': 23607,
#  'car': 4085,
#  'sports': 26961,
#  'learned': 15924,
#  'cheap': 4591,
#  'shot': 25748,
#  'lied': 16137,
#  'know': 15573,
#  'street': 27540,
#  'didnt': 7750,
#  'license': 16121,
#  'police': 21255,
#  'vehicle': 31650,
#  'saw': 24805,
#  'backup': 2042,
#  'enforcement': 9292,
#  'leave': 15935,
#  'suck': 27852,
#  'aint': 636,
#  'got': 12057,
#  'ta': 28377,
#  'admit': 381,
#  'funny': 11393,
#  'exchange': 9769,
#  'dressing': 8597,
#  'donkey': 8409,
#  'monkey': 17903,
#  'guy': 12462,
#  'poorly': 21376,
#  'costume': 6277,
#  'left': 15963,
#  'injured': 14431,
#  'lawsuit': 15871,
#  'hired': 13095,
#  'famous': 10194,
#  'gorilla': 12043,
#  'mall': 16801,
#  ...}

# %%
vocab = cv.vocabulary_
df_vocab = pd.DataFrame(list(vocab.items()), columns=['word', 'index'])
df_vocab = df_vocab.sort_values(by ='index',ascending=True)

# %%
df_vocab
# Out:
#               word  index
# 10204           aa      0
# 21898          aal      1
# 25209     aardvark      2
# 4862           aba      3
# 5585         aback      4
# ...            ...    ...
# 11662         zoom  33021
# 30879     zoonotic  33022
# 23821  zooplankton  33023
# 10869     zucchini  33024
# 21652         zuza  33025
#
# [33026 rows x 2 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
# creating a set for efficienc
english_words = set(words.words())
def english_only(text):
    return [token for token in word_tokenize(text) if token in english_words]

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from multiprocessing import Pool

nltk.download('stopwords')
nltk.download('words')
nltk.download('wordnet')


lemmatizer = WordNetLemmatizer()
english_words = set(nltk.corpus.words.words())
stop_words = set(stopwords.words('english'))

# tokenising by words, accounting for stopwords and finally lematising.
def process_text(text):
    tokenized_text = word_tokenize(text)
    removed_stopwords = [word for word in tokenized_text if word not in stop_words]
    return ' '.join([lemmatizer.lemmatize(word) for word in removed_stopwords])
with Pool() as pool: #used to make the code run faster.
  df['processed_article'] = pool.map(process_text, df['article'])

tfidf_model = TfidfVectorizer(norm=None)
df_tfidf_transformed = tfidf_model.fit_transform(df.processed_article)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
len(tfidf_model.vocabulary_)
# Out:
# 185761

# %%
stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
df_sub = df[['article','processed_article']].head(5)
df_sub
# Out:
#                                              article  \
# 0  the hyperloop elon musks idea to make a highsp...
# 1  on tuesday the supreme court heard oral argume...
# 2  remember how excited you were last summer no n...
# 3  the war film is one of cinemas most enduring g...
# 4  moments after putting the finishing touches on...
#
#                                    processed_article
# 0  hyperloop elon musk idea make highspeed transi...
# 1  tuesday supreme court heard oral argument unit...
# 2  remember excited last summer found booth state...
# 3  war film one cinema enduring genre nearly ever...
# 4  moment putting finishing touch landmark billio...

# %% [markdown]
# #STEMMING

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
from nltk.tokenize import word_tokenize
from multiprocessing import Pool
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('words')


stemmer = SnowballStemmer('english')
english_words = set(nltk.corpus.words.words())
stop_words = set(stopwords.words('english'))

# creating a function
def process_text(text):
    return ' '.join([stemmer.stem(word) for word in word_tokenize(text) if word in english_words and word not in stop_words])

with Pool() as pool:
  df['processed_article'] = pool.map(process_text, df['article'])
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %% [markdown]
# #TF-IDF

# %%
tfidf_model = TfidfVectorizer()
df_tfidf_transformed = tfidf_model.fit_transform(df.processed_article)

# %%
len(tfidf_model.vocabulary_)
# Out:
# 23945

# %%
min(df_tfidf_transformed.shape)
# Out:
# 23945

# %%
from sklearn.decomposition import TruncatedSVD
svd = TruncatedSVD(n_components=1000)
df_svd_transformed = svd.fit_transform(df_tfidf_transformed)
import matplotlib.pyplot as plt
# plotting the cumulative sum of explained variance ratio
plt.figure(figsize=(10,5))
plt.plot(np.cumsum(svd.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Explained Variance by Components')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
inertia = []
for k in range(5, 20):
  kmeans = KMeans(n_clusters=k, random_state= 42)
  kmeans.fit(df_svd_transformed)
  inertia.append(kmeans.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
plt.plot(range (5, 20), inertia, marker= 'v')
plt. title('Elbow Method')
plt.xlabel ('Number of Clusters')
plt.ylabel('Inertia')
plt.show()

# %%
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans

# initializing a list to store silhouette scores
silhouette_scores = []

# range of clusters
clusters_range = range(7, 12)  # Adjust the range as per your requirement

# calculating silhouette score for each value of k
for k in clusters_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(df_svd_transformed)  # Assuming df_svd_transformed is your data
    labels = kmeans.labels_
    silhouette_scores.append(silhouette_score(df_svd_transformed, labels))

# plotting silhouette scores
plt.plot(clusters_range, silhouette_scores, marker='o')
plt.title('Silhouette Score for KMeans Clustering')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
from sklearn.cluster import KMeans
num_clusters = 10
kmeans = KMeans(n_clusters=num_clusters)

# fitting the model
labels = kmeans.fit_predict(df_svd_transformed)
df['cluster_label'] = labels
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
from collections import defaultdict
import matplotlib.pyplot as plt

# getting feature names from the vectorizer
feature_names = tfidf_model.get_feature_names_out()

# initializing a dictionary to hold the top 30 words for each cluster
top_words_per_cluster = defaultdict(list)

# getting the top 30 words for each cluster
for i in range(num_clusters):
    # getting all items in current cluster
    cluster_items = df_tfidf_transformed[labels == i].toarray()

    # calculating the mean tf-idf score for each word in the cluster
    mean_tfidf_scores = cluster_items.mean(axis=0)

    # getting the indices of the top 30 scores
    top_indices = np.argsort(mean_tfidf_scores)[::-1][:30]

    # getting the top words and their scores
    top_words = [(feature_names[j], mean_tfidf_scores[j]) for j in top_indices]

    # adding the top words to the dictionary
    top_words_per_cluster[i] = top_words

    # plotting the top 30 words
    plt.figure(figsize=(10, 15))
    plt.barh(*zip(*top_words[::-1]))
    plt.title(f'Top 30 Words in Cluster {i} Based on TF-IDF Score')
    plt.xlabel('TF-IDF Score')
    plt.ylabel('Words')
    plt.show()

# %% [markdown]
# #N-Gram

# %%
from sklearn.decomposition import TruncatedSVD
# initializing TF-IDF Vectorizer
ngram_vectorizer = TfidfVectorizer(ngram_range=(1, 2), max_features=5000)

# fitting the vectorizer and transforming
ngram_matrix = ngram_vectorizer.fit_transform(df.processed_article)

# pca using TruncatedSVD
svd_ngram = TruncatedSVD(n_components=100)
ngram_matrix_reduced = svd_ngram.fit_transform(ngram_matrix)

# %%
# plotting the cumulative sum of explained variance ratio
plt.figure(figsize=(10,5))
plt.plot(np.cumsum(svd_ngram.explained_variance_ratio_))
plt.xlabel('Number of Components for ngram')
plt.ylabel('Cumulative Explained Variance for ngram')
plt.title('Explained Variance by Components for ngram')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
inertia = []
for k in range(5, 20):
  kmeans = KMeans(n_clusters=k, random_state= 42)
  kmeans.fit(ngram_matrix_reduced)
  inertia.append(kmeans.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
plt.plot(range (5, 20), inertia, marker= 'v')
plt. title('Elbow Method for ngram')
plt.xlabel ('Number of Clusters for ngram')
plt.ylabel('Inertia for ngram')
plt.show()

# %%
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans


silhouette_scores = []

# range of clusters
clusters_range = range(7, 12)

# calculating silhouette score for each value of k
for k in clusters_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(ngram_matrix_reduced)
    labels = kmeans.labels_
    silhouette_scores.append(silhouette_score(ngram_matrix_reduced, labels))

# plotting silhouette scores
plt.plot(clusters_range, silhouette_scores, marker='o')
plt.title('Silhouette Score for KMeans Clustering for ngram')
plt.xlabel('Number of Clusters for ngram')
plt.ylabel('Silhouette Score for ngram')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
from sklearn.cluster import KMeans
num_clusters = 10
kmeans = KMeans(n_clusters=num_clusters)

# fitting the model
labels = kmeans.fit_predict(ngram_matrix_reduced)
df['cluster_label'] = labels
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
from collections import defaultdict
import matplotlib.pyplot as plt


feature_names = ngram_vectorizer.get_feature_names_out()

# initializing a dictionary to hold the top 50 words for each cluster
top_words_per_cluster = defaultdict(list)

# getting the top 30 words for each cluster
for i in range(num_clusters):
    # getting all items in current cluster
    cluster_items = ngram_matrix[labels == i].toarray()

    # calculating the mean tf-idf score for each word in the cluster
    mean_ngram_scores = cluster_items.mean(axis=0)

    # getting the indices of the top 30 scores
    top_indices = np.argsort(mean_ngram_scores)[::-1][:30]

    # getting the top words and their scores
    top_words = [(feature_names[j], mean_ngram_scores[j]) for j in top_indices]

    # adding the top words to the dictionary
    top_words_per_cluster[i] = top_words

    # plotting the top 30 words
    plt.figure(figsize=(10, 15))
    plt.barh(*zip(*top_words[::-1]))
    plt.title(f'Top 30 Words in Cluster {i} Based on TF-IDF ngram Score')
    plt.xlabel('TF-IDF ngram Score')
    plt.ylabel('Words')
    plt.show()

# %%
with Pool() as pool: #used to make the code run faster.
  df['processed_title'] = pool.map(process_text, df['title'])

# %%
#word cloud
from collections import Counter
nltk.download('punkt')
title_tokens = [word for title in df['processed_title'] for word in word_tokenize(title.lower())]
title_word_freq = Counter(title_tokens)

title_word_freq.most_common(10)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [('trump', 2048),
#  ('new', 1312),
#  ('china', 564),
#  ('us', 504),
#  ('updat', 474),
#  ('trade', 423),
#  ('first', 418),
#  ('million', 410),
#  ('hous', 397),
#  ('deal', 391)]

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

title_wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(title_word_freq)
plt.figure(figsize=(10, 5))
plt.imshow(title_wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud for Processed Titles')
plt.show()

# %%
#taking a subset of articles because of the huge volume of words
df1_subset = df.head(9000)

article_tokens = [word for article in df1_subset['processed_article'] for word in word_tokenize(article.lower())]
article_word_freq = Counter(article_tokens)

# %%
article_wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(article_word_freq)
plt.figure(figsize=(10, 5))
plt.imshow(article_wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud for Articles')
plt.show()

# %% [markdown]
# #Analysis and Inference

# %% [markdown]
#  Our primary objective was to cluster news articles effectively and find distinct clusters. Given the lack of a well-defined metric, we adopted an iterative approach to achieve this goal. The first step in our methodology was to reduce the dimensionality of our dataset, which initially had over 23,000 features. We employed Principal Component Analysis (PCA) for this purpose, allowing us to identify and retain the top 1,000 principal components that accounted for approximately 50% of the variance in our data. This reduction was significant as it simplified our dataset while preserving its essential structure. With a more manageable set of features, we then applied the KMeans clustering algorithm, motivated by its efficiency and simplicity. To determine the optimal number of clusters, we utilized the elbow method and silhouette plots, suggesting that around 10 clusters were optimal for our dataset. Once the clusters were formed, we conducted a thorough examination of each cluster, identifying the top 30 words with the highest TF-IDF scores in each cluster to gain a qualitative understanding of the content. Our choices of PCA for dimensionality reduction, KMeans for clustering, and the elbow method and silhouette plots for determining the optimal number of clusters were all justified based on the nature of our dataset and our objective of effectively clustering news articles. Our iterative approach allowed us to refine our methodology and achieve our goal. While seven out of ten clusters had distinct themes with minimal overlap, indicating successful initial clustering, areas for improvement were identified, such as adjusting the n-grams range in TF-IDF vectorization and removing less meaningful words to enhance cluster clarity. Despite some unclear clusters, our preliminary findings are promising, and further exploration, including increasing the n-grams range to trigrams, is planned to improve cluster differentiation and identify new themes.
